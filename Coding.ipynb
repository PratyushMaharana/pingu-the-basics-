# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyushMaharana/pingu-the-basics-/blob/main/Coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#May 23 2024
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(0,15,20)
y= np.sin(x)+0.1*np.random.randn(len(x))
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,15,20)
y=np.sin(x)+0.1*np.random.randn(len(x))
plt.plot(x,y)

# %% [markdown]
# A= 67
# B

# %%
pip install SciencePlots

# %%
print("hello")
print()
print("gh")
# Out:
# hello
#
# gh

# %%
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %%
x = np.linspace(0,15,30)
y = np.sin(x)+0.1*np.random.randn(len(x))

# %%
plt.plot(x,y)

# %%
x2 = np.linspace(0,15, 100)
y2 = np.sin(x2)

# %%
plt.figure(figsize=(9,3))
plt.plot(x2,y2,'-', color='green',lw=1,ms= 5, label='component 7' )
plt.plot(x,y,'o-', color='green',lw=1,ms= 5, label='component 8' )
plt.xlabel('time[s]')
plt.ylabel('distnace[d]')
plt.legend(loc= 'lower left', fontsize=10, ncol=2)

# %%
x2= np.linspace(0,20,100)
y2= np.sin(x2)
plt.figure(figsize=(9,3))
plt.plot(x2,y2,'-', color='blue',lw=1,ms=5, label='component8')
plt.plot(x,y,'o-', color='red',lw=1,ms=5, label='component9')
plt.xlabel('time[s]')
plt.ylabel('distance[d]')
plt.legend(loc= 'lower left', fontsize=10, ncol=2)

# %%
res =  np.random.randn(1000)*0.2+ 0.4

# %%
a=plt.hist(res)

# %%
plt.hist(res,bins=80)
plt.figure(figsize=(8,3))
plt.hist(res,bins=30, density=True, histtype='step')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(1,1, figsize=(12,4))
ax.plot(x, y, 'o--')
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
# Out:
# Text(0, 0.5, 'asdasasd')

# %%
fig,axes = plt.subplots(3,2, figsize=(12,12))
ax = axes[0][0]
ax.plot(x, y, 'o--')
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
ax.text(0.1,0.1, 'text here', transform=ax.transAxes)
ax.tick_params(axis='both', labelsize=10)
ax = axes[1][1]
ax.hist(res, bins=30, density=True, histtype='step' , label='compl')
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
ax.legend()
plt.show()

# %%
res_a1 = 0.2*np.random.randn(1000)+0.4
res_b1 = 0.25*np.random.randn(1000)+0.4
res_a2 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.2*np.random.randn(1000)+0.3

# %%
plt.hist(res_a1, bins=100)
plt.hist(res_b1, bins=100)
plt.show()

# %%
# '\n' means new line
textstr1 = '\n'.join
  r'$\sigma_a=%.4f$' % (np)
# Out:
#   File "<ipython-input-25-75882af37fee>", line 3
#     r'$\sigma_a=%.4f$' % (np)
#     ^
# IndentationError: unexpected indent

# %%
n,m=20,30
n,m=m+10,n+10
print(n,m,sep='&')
# Out:
# 40&30

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,15,22)
y=np.sin(x)+0.1*np.random.randn(len(x))
plt.plot(x,y)
ax.plot(x, y, 'o--')

# %%
n=int(input('enter the value:'))
if n>=10:
  print("true")
else:
  print("false")
# Out:
# enter the value:1
# false

# %%
print("\U0001F924")
# Out:
# 🤤

# %%
num=123
reversed_num=0
while num!=0:
  digit=num%10
  reversed_num=reversed_num*10+digit
  num//=10
print("Reversed number:"+str(reversed_num))
# Out:
# Reversed number:321

# %%
num=int(input("enter a number:"))
if (num%2)==0:
  print("even number" )
else:
  print("odd number")
# Out:
# enter a number:78
# even number

# %%
num=int(input("enter a number:"))
flag = False

if num == 0 or num == 1:
    print(num, "is not a prime number")
elif num > 1:
    for i in range(2, num):
        if (num % i) == 0:

            flag = True

            break


    if flag:
        print(num, "is not a prime number")
    else:
        print(num, "is a prime number")

        print("\U0001F928")
# Out:
# enter a number:67
# 67 is a prime number
# 🤨

# %%
num=int(input("enter a number:"))
flag=False
if num==0 or num==1:
    print(num,"is not a prime number")
elif num>1:
    for i in range(2,num):
        if (num % i) == 0:
           flag=True
           break
    if flag:
      print(num,"is not a prime number")
    else:
      print(num, "is a prime number")
# Out:
# enter a number:90
# 90 is not a prime number

# %%
num =int(input("enter a number:"))
if num>=100:
  print("the number is greater than 100")
else:
  print("the number is not greater than 100")
# Out:
# enter a number:111
# the number is greater than 100

# %%
num= int(input("enter a number:"))
for i in range(1,11):
  print(num,'x',i,'=',num*i)
# Out:
# enter a number:20
# 20 x 1 = 20
# 20 x 2 = 40
# 20 x 3 = 60
# 20 x 4 = 80
# 20 x 5 = 100
# 20 x 6 = 120
# 20 x 7 = 140
# 20 x 8 = 160
# 20 x 9 = 180
# 20 x 10 = 200

# %%
num =int(input("enter a number"))
if(num== 1):
    print('Monday')
elif(num == 2):
    print('Tuesday')
elif(num == 3):
    print('Wednesday')
elif(num ==4):
    print('Thursday')
elif(num ==5):
    print('Friday')
elif(num ==6):
    print('saturday')
elif(num ==7):
    print('sunday')
elif(num < 1):
    print('put a number between 1-7 ')
# Out:
# enter a number7
# sunday

# %%
num=int(input("enter a number:"))
a=False
if num==0 or num==1:
  print(num,"is not a prime number")
elif num>1:
  for i in range(2,num):
    if (num%i)==0:
      a=True
      break
  if a:
    print(num," is not a prime number")
  else:
    print(num,"is a prime number")
# Out:
# enter a number:8787979779949883776629929884899999
# 8787979779949883776629929884899999  is not a prime number

# %%
num=int(input("enter a number"))
for i in range(1,11):
  print(num,'x',i,'=',num*i)
# Out:
# enter a number99
# 99 x 1 = 99
# 99 x 2 = 198
# 99 x 3 = 297
# 99 x 4 = 396
# 99 x 5 = 495
# 99 x 6 = 594
# 99 x 7 = 693
# 99 x 8 = 792
# 99 x 9 = 891
# 99 x 10 = 990

# %%
num=int (input("enter a number:"))
a=0
while num!=0:
 digit=num%10
 a=a*10+digit
 num//=10
print("reversed number:"+str(a))
# Out:
# enter a number:100
# reversed number:1

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,15,100)
y=np.sin(x)+0.1*np.random.randn(len(x))
plt.plot(x,y)

# %%
num=int(input('enter a number:'))
a=False
if num==0 or num==1:
  print(num,"is not a prime number")
elif num>1:
  for i in range(num,2):
    if (num%i)==0:
      a=True
      break
  if a:
    print(num,"is not a prime number")
  else:
    print(num,"is a prime number")
# Out:
# enter a number:8
# 8 is a prime number

# %%
num=int(input("enetr a number"))
a=False
if num==0 or num==1:
  print(num,"is not a prime number ")
elif num>1:
  for i in range(2,num):
    if (num%i)==0:
# Out:
#   File "<ipython-input-2-3127c5ba49a0>", line 7
#     if (num%i)==0:
#                   ^
# SyntaxError: incomplete input

# %%
n=10
i=10
while i >1:
  print("hello")
  n=n+5
  i=i-2
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
n=86
c=1
while c<11:
  print(n,'x',c,'=',c*n)
  c=c+1
# Out:
# 86 x 1 = 86
# 86 x 2 = 172
# 86 x 3 = 258
# 86 x 4 = 344
# 86 x 5 = 430
# 86 x 6 = 516
# 86 x 7 = 602
# 86 x 8 = 688
# 86 x 9 = 774
# 86 x 10 = 860

# %%
y=5
y+=5
j=7
while j<8:
  print(y)
  j+=1
# Out:
# 10

# %%
num=int(input("enter a number:"))
a=False
if num==0 or num==1:
  print(num,"is not a prime number")
elif num>1:
  for i in range(2,num):
    if (num%i)==0:
      a=True
      break
  if a:
    print(num, "is not a  prime number")
  else:
    print(num,"is a prime number")
# Out:
# enter a number:77878
# 77878 is not a  prime number

# %%
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 34
# 34 is not a prime number

# %%
num = int(input("Enter a number: "))
reversed_num = int(str(num)[::-1])
print("Reversed number:", reversed_num)
# Out:
# Enter a number: 1234
# Reversed number: 4321

# %%
num=int(input("enter a number:"))
a=int(str(num)[::-1])
print("reversed number", a)
# Out:
# enter a number:1234
# reversed number 4321

# %%
num=int(input("enter a number:"))
a=False
if num==0 or num==1:
  print(num,"is not a prime number")
elif num>1:
  for i in range(2,num):
    if (num%i)==0:
      a=True
      break
  if a :
    print(num,"is not a prime number")
  else:
    print(num, "is a prime number")
# Out:
# enter a number:6566
# 6566 is not a prime number

# %%
num=int(input("enter a number:"))
a=int(str(num)[::-1])
print("reversed number",a)
# Out:
# enter a number:1234
# reversed number 4321
